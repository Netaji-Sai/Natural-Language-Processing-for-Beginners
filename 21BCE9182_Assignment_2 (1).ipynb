Filmography
Main article: Mahesh Babu filmography
Awards and nominations
Main article: List of awards and nominations received by Mahesh Babu
Mahesh Babu is a recipient of nine Nandi Awards, five Filmfare South Awards, three CineMAA Awards, three Santosham Film Awards, four SIIMA Awards and one IIFA Utsavam Award.
"""

def count_words(input):
  freq = {}
  for tok in input.split():
    if tok not in freq:
      freq[tok] = 1
    else :
      freq[tok] +=1
  return freq

res = count_words(input)
def printing(res):
  for x in res.keys():
    print(x)
printing(res)
# Out:
# Ghattamaneni
# Mahesh
# Babu
# (born
# 9
# August
# 1975)
# is
# an
# Indian
# actor,
# producer,
# media
# personality,
# and
# philanthropist
# who
# works
# in
# Telugu
# cinema.
# He
# one
# of
# the
# highest-paid
# actors
# cinema.[1][2]
# has
# appeared
# more
# than
# 25
# films,
# won
# several
# accolades
# including,
# nine
# Nandi
# Awards,
# five
# Filmfare
# four
# SIIMA
# three
# CineMAA
# IIFA
# Utsavam
# Award.
# also
# owns
# production
# house
# G.
# Entertainment.
# referred
# to
# by
# his
# fans
# as
# "Superstar"
# "Prince".[3][4]
# The
# younger
# son
# veteran
# actor
# Krishna,
# made
# debut
# a
# child
# artist
# cameo
# role
# Needa
# (1979),
# at
# age
# four,[5]
# acted
# eight
# other
# films
# artist.
# lead
# with
# Rajakumarudu
# (1999)
# which
# him
# Award
# for
# Best
# Male
# Debut.[6]
# achieved
# breakthrough
# supernatural
# drama
# Murari
# (2001),
# action
# film
# Okkadu
# (2003).
# went
# on
# act
# commercially
# successful
# such
# ...

# %%
for k,v in res.items():
  print(k+" : "+str(v))
# Out:
# Ghattamaneni : 2
# Mahesh : 27
# Babu : 46
# (born : 1
# 9 : 2
# August : 5
# 1975) : 1
# is : 26
# an : 14
# Indian : 6
# actor, : 1
# producer, : 2
# media : 4
# personality, : 1
# and : 89
# philanthropist : 1
# who : 5
# works : 1
# in : 106
# Telugu : 24
# cinema. : 1
# He : 44
# one : 13
# of : 101
# the : 197
# highest-paid : 2
# actors : 1
# cinema.[1][2] : 1
# has : 9
# appeared : 4
# more : 4
# than : 2
# 25 : 2
# films, : 1
# won : 9
# several : 4
# accolades : 1
# including, : 1
# nine : 2
# Nandi : 10
# Awards, : 8
# five : 5
# Filmfare : 13
# four : 2
# SIIMA : 7
# three : 4
# CineMAA : 2
# IIFA : 2
# Utsavam : 2
# Award. : 2
# also : 13
# owns : 1
# production : 3
# house : 1
# G. : 2
# Entertainment. : 1
# referred : 2
# to : 62
# by : 17
# his : 84
# fans : 3
# as : 27
# "Superstar" : 1
# "Prince".[3][4] : 1
# The : 23
# younger : 2
# son : 1
# veteran : 1
# actor : 12
# Krishna, : 2
# made : 4
# debut : 5
# a : 62
# child : 5
# artist : 2
# cameo : 1
# role : 8
# ...

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
print(len(nltk.word_tokenize(input)))
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 4528

# %%
print(len(input.split(" ")))
# Out:
# 3430

# %%
import nltk
def wordfreq(mystring):
  '''
  Function to generated the frequency distribution of the given text
  '''
  print(mystring)
  word_freq = {}
  for tok in mystring.split():
    if tok in word_freq:
      word_freq[tok]+=1
    else:
      word_freq[tok]=1
  print(word_freq)

def main():
  str="This is my fist python program as part of NLP"
  wordfreq(str)
if __name__ == '__main__':
  main()
# Out:
# This is my fist python program as part of NLP
# {'This': 1, 'is': 1, 'my': 1, 'fist': 1, 'python': 1, 'program': 1, 'as': 1, 'part': 1, 'of': 1, 'NLP': 1}

# %%
from bs4 import BeautifulSoup
import urllib

response = urllib.request.urlopen("https://en.wikipedia.org/wiki/Mahesh_Babu")
html = response.read().decode('utf-8')

soup = BeautifulSoup(html,'html.parser')
clean_text = soup.get_text()

print(clean_text.split())
# Out:
# ['Mahesh', 'Babu', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(Top)', '1Early', 'life', 'and', 'family', '2Acting', 'career', 'Toggle', 'Acting', 'career', 'subsection', '2.1Early', 'career', 'and', 'breakthrough', '(1979–2003)', '2.2Mainstream', 'film', '(2004–2010)', '2.3Stardom', 'and', 'career', 'setback', '(2011–2014)', '2.4Resurgence', 'and', 'recent', 'work', '(2015–present)', '3Philanthropy', '4In', 'the', 'media', '5Personal', 'life', 'Toggle', 'Personal', 'life', 'subsection', '5.1
# ...

# %%
from bs4 import BeautifulSoup
import urllib

response = urllib.request.urlopen('http://python.org/')
html = response.read().decode('utf-8')

soup = BeautifulSoup(html, 'html.parser')
clean_text = soup.get_text()

tokens = [tok for tok in clean_text.split()]
print(tokens[0:])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-1df8b38bb313> in <cell line: 5>()
#       3
#       4 response = urllib.request.urlopen('http://python.org/')
# ----> 5 html = response.read().decode('utf-8')
#       6
#       7 soup = BeautifulSoup(html, 'html.parser')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte

# %%
Freq_dist_nltk = nltk.FreqDist(tokens)
print(Freq_dist_nltk)
for k,v in Freq_dist_nltk.items():
  print(str(k)+':'+str(v))
# Out:
# <FreqDist with 549 samples and 1024 outcomes>
# Welcome:1
# to:15
# Python.org:1
# Notice::1
# While:1
# JavaScript:2
# is:12
# not:2
# essential:1
# for:11
# this:1
# website,:1
# your:4
# interaction:1
# with:7
# the:18
# content:2
# will:1
# be:3
# limited.:1
# Please:1
# turn:1
# on:3
# full:1
# experience.:1
# Skip:1
# ▼:1
# Close:1
# Python:52
# PSF:8
# Docs:6
# PyPI:2
# Jobs:2
# Community:7
# ▲:3
# The:5
# Network:1
# Donate:2
# ≡:1
# Menu:1
# Search:1
# This:1
# Site:1
# GO:1
# A:2
# Smaller:1
# Larger:1
# Reset:1
# Socialize:1
# LinkedIn:1
# Mastodon:1
# Chat:1
# IRC:3
# Twitter:1
# About:2
# Applications:3
# Quotes:2
# Getting:2
# Started:3
# Help:3
# Brochure:2
# Downloads:2
# All:3
# releases:2
# Source:3
# code:3
# Windows:2
# macOS:2
# Other:2
# Platforms:2
# License:2
# Alternative:2
# Implementations:2
# Documentation:3
# Audio/Visual:2
# Talks:2
# Beginner's:2
# Guide:6
# Developer's:3
# FAQ:2
# Non-English:2
# PEP:2
# Index:2
# Books:2
# Essays:2
# Diversity:3
# ...

# %%
print(res.get('Mahesh'))
# Out:
# 27

# %%
nltk.FreqDist(res).plot(50,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
Freq_dist_nltk.plot(50, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
